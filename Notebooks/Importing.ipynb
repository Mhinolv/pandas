# %% [markdown]
# ### Importing Data
#
# There are many methods to import data using pandas but we will focus on loading CSV files.

# %%
import pandas as pd
from pandas import DataFrame

# %% [markdown]
# **Creating Filepath and DataFrame**

# %%
## Creating a variable for the directory of the source data
filepath = '/Users/MarkHinojosa/pandas/Data/Employee Attrition.csv'

## Call the dataframe using the filepath var
employeeDF = pd.read_csv(filepath)

# %% [markdown]
# **Validating Data Population**

# %%
employeeDF.head(5)
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0     1.0                0.38             0.53             2.0
# 1     2.0                0.80             0.86             5.0
# 2     3.0                0.11             0.88             7.0
# 3     4.0                0.72             0.87             5.0
# 4     5.0                0.37             0.52             2.0
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                 157.0                 3.0            0.0
# 1                 262.0                 6.0            0.0
# 2                 272.0                 4.0            0.0
# 3                 223.0                 5.0            0.0
# 4                 159.0                 3.0            0.0
#
#    promotion_last_5years   dept  salary
# 0                    0.0  sales     low
# 1                    0.0  sales  medium
# 2                    0.0  sales  medium
# 3                    0.0  sales     low
# 4                    0.0  sales     low

# %% [markdown]
# **Describing the Data**

# %%
employeeDF.describe().round(2)
# Out:
#          Emp ID  satisfaction_level  last_evaluation  number_project  \
# count  14999.00            14999.00         14999.00        14999.00
# mean    7500.00                0.61             0.72            3.80
# std     4329.98                0.25             0.17            1.23
# min        1.00                0.09             0.36            2.00
# 25%     3750.50                0.44             0.56            3.00
# 50%     7500.00                0.64             0.72            4.00
# 75%    11249.50                0.82             0.87            5.00
# max    14999.00                1.00             1.00            7.00
#
#        average_montly_hours  time_spend_company  Work_accident  \
# count              14999.00            14999.00       14999.00
# mean                 201.05                3.50           0.14
# std                   49.94                1.46           0.35
# min                   96.00                2.00           0.00
# 25%                  156.00                3.00           0.00
# 50%                  200.00                3.00           0.00
# 75%                  245.00                4.00           0.00
# max                  310.00               10.00           1.00
#
#        promotion_last_5years
# count               14999.00
# mean                    0.02
# std                     0.14
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
